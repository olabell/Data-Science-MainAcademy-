# %% [markdown]
# <h2 align='center'>Домашнє завдання за 05.06</h2>

# %% [markdown]
# ##### Завдання 1. Тестування. <br>

# %% [markdown]
# 1. Де правильно записано команду виведення тексту повідомлення?<br>
#     	а) PRINT ("Hello World!") <br>
#     	б) print ("Hello World!")<br>
#     	в) Print ("Hello World!")<br>
# Поясніть свої міркування.<br><br>
# 2. Де правильно записано коментар у програмі?<br>
#     	а) @ Проводимо реєстрацію <br>
#     	б) $ Обчислюємо прибуток<br>
#     	в) # Виведення даних у файл<br>
#     	г) & Завершення роботи програми.<br>
# Поясніть, чому ви так вирішили.<br><br>
# 3. Де правильно записано команду введення текста з консолі?<br>
#    	а) name=input ("Як вас звати?") <br>
#     	б) name=Input ("Як вас звати?")<br>
#     	в) name=INPUT ("Як вас звати?")<br>
# Що буде, якщо не використати змінну name? Що таке змінна?<br><br>
# 4. Поясніть, яких помилок допустився початківець-програміст у кожному випадку:<br>
#     	а) text = Hello World<br>
#     	б) text = "Hello World<br>
#     	в) text = "Hello World'<br><br>
# 5. Відшукайте команди, виконання яких не буде супроводжуватися повідомленням про помилку:<br>
#     	а) x = "10"+5<br>
#     	б) x = "Hello " + "World"<br>
#     	в) x = "Ваш прибуток: " + 10<br>
#     	г) x = "Ваш прибуток: " + "10"<br><br>
# 6. Поясніть, що означають введені нижче команди:<br>
#     	а) x = int ("4311")<br>
#     	б) y = int (y)<br>
#     	в) z = float (z)<br>
#     	г) k = str (1284)<br>
#     	д) a = int(input("Введіть свій зріст"))<br><br>

# %% [markdown]
# 1. б) Правильно писати print, адже у Python важливий регістр. PRINT та Print не є правильними та та призвезуть до помилки<br><br>
# 2. в) Для коментарів використовується #
# <br><br>
# 3. а) Правильно писати input бо у Python важливий регістр тому Input та INPUT не є правильними та призвезуть до помилки.<br>
# Якщо не використати змінну name, то при запуску коду програма виконає input та виведе введене значеннния. Але змінна нікуди не збережеться і надалі її не можна використати буде. Змінна — це об'єкт (область) для зберігання даних.
# <br><br>
# 4.
# а) text = Hello World - немає жодних лапок ( " чи ')<br>
# б) text = "Hello World - немає закриваючаї лапки " в кінці<br>
# в) text = "Hello World' - не співпадають лапки ( можна так "Hello World" або так 'Hello World')<br>
# <br><br>
# 5.
# а) x = "10"+5 - тут буде помилка адже це різні типи даних ("10" - string, 5 - integer)<br>
# б) x = "Hello " + "World" -  ПРАВИЛЬНО, обєднуються дві стрічки<br>
# в) x = "Ваш прибуток: " + 10 = тут буде помилка адже це різні типи даних (string та integer)<br>
# г) x = "Ваш прибуток: " + "10" -  ПРАВИЛЬНО, обєднуються дві стрічки
# <br><br>
# 6.
# а) x = int ("4311") - задається змінна x, тип цілого числа і дорівнює 4311<br><br>
# б) y = int (y) - тут задається змінна y яку задаються як тип int. Неправильний формат, не можна передати змінній значення самої себе. <br>Якщо треба створити змінну яка буде цілим числом, але присвоїти якесь значення вже потім, то буде в такому виді y = int()<br><br>
# в) z = float (z)  - аналогічно з б), бо тут неправильний формат, не можна передати змінній значення самої себе. Якщо треба створити змінну яка буде типу float, але присвоїти якесь значення вже потім, то буде в такому виді z = float()<br><br>
# г) k = str (1284) - створюємо змінну k, присвоюємо їй значення 1284 типу стрічки<br><br>
# д) a = int(input("Введіть свій зріст")) - створюємо змінну a, використовуємо функцію input для того щоб користувач міг ввести якесь значення. Значення має бути типу цілого числа.

# %% [markdown]
# ##### Завдання 2. Арифметичні дії. <br>
# Виконайте у середовищі інтерпретатора такі команди (просто введіть їх так, як показано тут, і дізнайтеся результат. Кожну команду перепишіть у зошит, а навпроти неї запишіть результат виконання.
# <p align='center'>
# 125/4<br>
# 125//4 <br>
# 125%4  <br>
# 45*4  <br>
# 11**2  <br>
# 1024-4  <br>
# 125+15  <br>
# </p>

# %%
125/4
125//4
125%4
45*4
11**2
1024-4
125+15
# Out:
# 140

# %% [markdown]
# У середовищі інтерпретатора виведеться результат тільки останної команди 125+15. Щоб порахувати всі можемо використати print

# %%
print(125/4)
print(125//4)
print(125%4)
print(45*4)
print(11**2)
print(1024-4)
print(125+15)
# Out:
# 31.25
# 31
# 1
# 180
# 121
# 1020
# 140

# %%
from IPython.display import Image
print('Текстове рішення')
Image("/Users/olha/Desktop/pyth/hw1/photo_2023-07-10_10-58-19.jpg", width=300, height=300)
# Out:
# Текстове рішення

# %% [markdown]
# ##### Завдання 3. Програма, що аналізуватиме ваш ростово-масовий показник . <br>
#
# Програма має спочатку попрости у вас ввести масу у кілограмах (змінна m), далі – зріст у сантиметрах (змінна h). <br>
# Обидві змінні слід перетворити в дійсні числа функцією float. Наприклад, m = float (m). <br>
# Щоб перевести сантиметри у метри, зріст поділіть на 100: h=h/100 <br>
# Щоб обчислити індекс маси тіла (змінна i), слід масу в кілограмах поділити на квадрат зросту: i=m/h**2 <br>
#
# Для зручності читання отриманий індекс або перетворюємо у ціле число функцією int: i=int(i) або округлюємо до сотих за допомогою функції round: i=round(i,2) Цифра 2 означає округлення до сотих (два знаки після коми).
#
# Після цього програма має виводити на екран резюме, наприклад: Ваш індекс маси тіла становить 24.25 А після цього повідомлення друкується пояснення: Ваша маса тіла вважається нормальною, якщо індекс знаходиться в межах від 15.5 до 25.
#
# Поки що ми не вчимо нашу програму робити висновки – це робить користувач!

# %%
m = float(input("Введіть Вашу вагу у кг:"))
h = float(input("Введіть Ваш зріст у см:"))
h = h/100
i = round((m/(h**2)),2)
print(f'Ваш індекс маси тіла становить: {i}')
print('Ваша маса тіла вважається нормальною, якщо індекс знаходиться в межах від 15.5 до 25')
# Out:
# Введіть Вашу вагу у кг:65
# Введіть Ваш зріст у см:180
# Ваш індекс маси тіла становить: 20.06
# Ваша маса тіла вважається нормальною, якщо індекс знаходиться в межах від 15.5 до 25

# %% [markdown]
# ##### Завдання 4. Максимальне число. <br>
#
# Пошук найбільшого числа: Напишіть програму, яка зчитує кожен елемент зі списку і потім виводить найбільше з введених.

# %%
lst = [10, 4, 13, 7, 6, 15, 2] # використовувати цей список

# %%
lst = [10, 4, 13, 7, 6, 15, 2]
max_value = max(lst)
print("Максимальне число зі списку:", max_value)
# Out:
# Максимальне число зі списку: 15
